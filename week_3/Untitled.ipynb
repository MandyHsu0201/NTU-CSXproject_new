# %%
#使用facebook圖形API測試工具來找貼文的內容

#Step 1.臉書搜尋人名,點開後，其url上會顯示其id
#Step 2.將id放入facebook for develops的get中，接著在後面接想看的東西(比如貼文用posts)提交後
#Step 3.可得到該人名的貼圖創建日及網頁，隨便點開一個網頁即可檢查出是否正確取得想要的人的臉書資訊
#Step 4.將該網頁的access token複製到python，也就是下個框中token後的那串，將token存成一個變數
#Step 5. requests.get的內容是https://graph.facebook.com/版本/id?access_token=%s'%

# %%
import requests
token='EAACEdEose0cBANeWfZAJ5NZBRgDYvYpgUw9UVeEH4fp8kdvz3xzZAw0b9OtgL81HTlTyCk1Fco8q1nYLdCZAO8diExssYsFYuzDjjm7MvpTJGdfbc5wbLtBQH11cFehm0KDJhZBp5NjZB4Xb2r8svrhPlqkLNJTQpiR7B5ac37zwIEeyuYrJAESRJc6MZAkZCalPxRknqXemZCgZDZD'
res=requests.get('https://graph.facebook.com/v2.12/1659884744238782/posts?access_token=%s'%(token))
print(res.text)
# Out:
# {"data":[{"created_time":"2015-03-29T12:00:35+0000","message":"http:\/\/www.appledaily.com.tw\/realtimenews\/article\/politics\/20150329\/583063\/1\/\u0025E3\u002580\u002590\u0025E6\u00259B\u0025B4\u0025E6\u002596\u0025B0\u0025E3\u002580\u002591\u0025E7\u0025B7\u0025AC\u0025E6\u002587\u0025B7\u0025E6\u0025B5\u0025B7\u0025E8\u0025BB\u00258D\u0025E5\u0025B7\u0025B2\u0025E6\u002595\u002585\u0025E5\u0025B0\u002587\u0025E5\u0025A3\u0025AB\u0025E3\u002580\u002580\u0025E9\u002599\u0025B3\u0025E8\u00258F\u00258A\u0025E7\u00258D\u0025BB\u0025E8\u00258A\u0025B1\u0025E8\u002587\u0025B4\u0025E6\u002595\u0025AC","id":"1659884744238782_1683983998495523"},{"created_time":"2015-03-28T12:58:49+0000","story":"\u9673\u83ca shared a link.","id":"1659884744238782_1683615061865750"},{"created_time":"2015-03-20T05:11:58+0000","message":"http:\/\/www.appledaily.com.tw\/realtimenews\/article\/politics\/20150320\/577772\/\u0025E9\u002599\u0025B3\u0025E8\u002587\u0025B4\u0025E4\u0025B8\u0025AD\u0025E9\u002580\
# ...
