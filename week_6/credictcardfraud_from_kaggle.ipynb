# %% [markdown]
# # The data is download  from  kaggle.
# This is a credictcardfraud problem and the data is imbalanced.
# 2013年歐洲的信用卡詐騙，變數V1-V28是用PCA萃取後的特徵，
# 只有這兩個變數未經過轉換(Time:時間，Amount:金額)
# Class:是否有詐騙(1:Yes,0:NO)

# %%
import matplotlib.pyplot as plt  #畫圖package
import pandas as pd              #這個package有一些統計運算，資料可存成data.frame
import numpy as np

# %%
#使用pandas package 讀取資料，就是已存成data.frame或series的格式了，不須再轉成data.frame
data_1 = pd.read_csv(r'C:\Mandy Hsu\NTU\creditcardfraud\creditcard.csv')

# %%
print('The dimension of the data:',data_1.shape)
print('=======================================')
print('The top 5 data:\n',data_1.head(2) )
# Out:
# The dimension of the data: (284807, 31)
# ...
# The top 5 data:
#     Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 31 columns]

# %%
data_1.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
#就像R裡面filter或subset的功能
#第一種寫法，若此變數是連續型的，則使用法是相同的，例如:df.query('value>5')
#有詐騙的資料
#data_1.query('Class==1')
#沒有詐騙的資料
#data_1.query('Class==0')
NB_Class_1=data_1.query('Class == 1').shape[0]
print('The number of Class=1(Yes):',NB_Class_1)
#第二種寫法
#data_1[data_1['Class'] == 1]
# Out:
# The number of Class=1(Yes): 492

# %%
#有詐騙的資料
data_classY=data_1[data_1['Class'] == 1]
data_classY.head(2)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 541  406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623  472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#            V7        V8        V9  ...         V21       V22       V23  \
# 541 -2.537387  1.391657 -2.770089  ...    0.517232 -0.035049 -0.465211
# 623  0.325574 -0.067794 -0.270953  ...    0.661696  0.435477  1.375966
#
#           V24       V25       V26       V27       V28  Amount  Class
# 541  0.320198  0.044519  0.177840  0.261145 -0.143276     0.0      1
# 623 -0.293803  0.279798 -0.145362 -0.252773  0.035764   529.0      1
#
# [2 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
#這個功能類似R裡面的table的指令
pd.value_counts(data_1.Class)
# Out:
# 1.00       13688
# 1.98        6044
# 0.89        4872
# 9.99        4747
# 15.00       3280
# 0.76        2998
# 10.00       2950
# 1.29        2892
# 1.79        2623
# 0.99        2304
# 20.00       2002
# 0.00        1825
# 8.99        1811
# 11.50       1741
# 4.49        1579
# 5.00        1569
# 0.77        1443
# 2.69        1436
# 25.00       1388
# 50.00       1341
# 4.99        1242
# 2.00        1091
# 30.00       1012
# 29.99        975
# 45.00        949
# 12.99        941
# 40.00        912
# 19.99        897
# 19.95        878
# 100.00       877
#            ...
# 308.57         1
# 443.71         1
# 229.42         1
# 242.24         1
# 668.87         1
# 293.85         1
# 562.28         1
# 1234.03        1
# 256.15         1
# 241.71         1
# 362.97         1
# 365.03         1
# 337.16         1
# 145.12         1
# 3783.15        1
# 617.89         1
# 508.39         1
# 511.61         1
# 167.97         1
# 167.03         1
# 133.19         1
# ...
